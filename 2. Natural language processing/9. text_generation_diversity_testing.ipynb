# %% [markdown]
# # **Text generation using LSTM**

# %%
from tensorflow import keras
from tensorflow.keras import layers

import numpy as np
import random
import io

# %%
path = keras.utils.get_file(
    "nietzsche.txt", origin="https://s3.amazonaws.com/text-datasets/nietzsche.txt"
)
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 600901/600901 [==============================] - 0s 1us/step

# %%
with io.open(path, encoding="utf-8") as f:
    text = f.read().lower()
text = text.replace("\n", " ")  # We remove newlines chars for nicer display
print("Corpus length:", len(text))
# Out:
# Corpus length: 600893

# %%
chars = sorted(list(set(text)))
print("Total chars:", len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# Total chars: 56

# %%
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i : i + maxlen])
    next_chars.append(text[i + maxlen])

print("Number of sequences:", len(sentences))
# Out:
# Number of sequences: 200285

# %%
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# <ipython-input-6-b8405c8d7c41>:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
# <ipython-input-6-b8405c8d7c41>:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

# %%
print(t,char)
# Out:
# 39 s

# %%
model = keras.Sequential(
    [
        keras.Input(shape=(maxlen, len(chars))),
        layers.LSTM(128),
        layers.Dense(len(chars), activation="softmax"),
    ]
)
optimizer = keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(loss="categorical_crossentropy", optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype("float64")
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
epochs = 40
batch_size = 128

for epoch in range(epochs):
    model.fit(x, y, batch_size=batch_size, epochs=1)
    print()
    print("Generating text after epoch: %d" % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print("...Diversity:", diversity)

        generated = ""
        sentence = text[start_index : start_index + maxlen]
        print('...Generating with seed: "' + sentence + '"')

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.0
            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]
            sentence = sentence[1:] + next_char
            generated += next_char

        print("...Generated: ", generated)
        print()
# Out:
# 1565/1565 [==============================] - 17s 6ms/step - loss: 1.9724
#
# Generating text after epoch: 0
# ...Diversity: 0.2
# ...Generating with seed: "m, as free from responsibility as if pla"
# ...Generated:  ce of the consime the sore and procicing of the self-confind and a procipic of the sore and a procopred and procipice of the self-and the self-conception of the such and a procopred and in the sore the sore and a conding of the constrent of the sore and and and find and the consime the sore this sore in the such and in the constreng and disconcent and constinct and the such and a procision of the
#
# ...Diversity: 0.5
# ...Generating with seed: "m, as free from responsibility as if pla"
# ...Generated:  nce procope of the supility of the worth and of that dis "in the sore cansition of very than the soul the procopre and consind to the surcance of the imple of the consting and have a soul be constroment and constrance to a propered it in the constilngion of the scyctive and and constinct and called the soration of such and constion of the must not even is under the self-in only to and not of himpe
#
# ...Diversity: 1.0
# ...Generating with seed: "m, as free from responsibility as if pla"
# ...Generated:  ns as im by sowent of patily cermorable soul agaithing thee chindy these sales"--also on  in he the putive to on, in it will as this neticequinity ny a. but he mist find toogurs, for heres of hershapure of a centuent and commane, even a geadance puthte wpre discinct lits mation man3. a nain" intuts plest of which the for doe. senmant of i makef being the sichs known be t rewhing--prociblusion and
#
# ...Diversity: 1.2
# ...Generating with seed: "m, as free from responsibility as if pla"
# ...Generated:  nes, and caplofiunces hroce wilimans healsceve of ekplave in even intand conscorrips, puty--an egral anoahice of molaca is not an anyible fectable, i kis rimatabas tor th"  )  and dgeapounary flom a gals buchs litsficuany, itself-so"- outwaicat like of dumicely on, "glatictize, trics, ou also: anior, consimarivisible, equeledpan will it is call, in it always, semmanzs" see" undall, ho atare, for e
#
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.5912
#
# Generating text after epoch: 1
# ...Diversity: 0.2
# ...Generating with seed: " it has for its opponents those who were"
# ...Generated:   the strength of the stand and considered the fact of the still the strength of the despress of the remain of the stand the strength of the strive and strength and the endition of the strength of the highest and soul of the world of the stand of the streethth and interpreted the strange interpression of the considered and a strives and and still and interpreten the highest and conscience, the stan
#
# ...Diversity: 0.5
# ...Generating with seed: " it has for its opponents those who were"
# ...Generated:   socience. the free chang the possible the existing and the highest and the cause with the stranges as a only sublemed the will the farred as the good of the highest to although his allow of the one of the self--norigin and such a bitted as the europe and conselles of the "cause at the consider the belief the state is a this cause at the distod of the world, and interpreted to one the highest whic
#
# ...Diversity: 1.0
# ...Generating with seed: " it has for its opponents those who were"
# ...Generated:   decirate cannot bechist of compressuchivination of his asterualifme of the guilth and cannot francts or contrality, who him. at thy wantwhing with one is these is a name; a existance, that the schillorical say, usismoued act out, of it--an any lash"--loigesigacecutence for0 love hone of val7 are recinct, no a to ana hhing powled, who wombleselves, be has his admstest intenture to blom allow may c
#
# ...Diversity: 1.2
# ...Generating with seed: " it has for its opponents those who were"
# ...Generated:  ch" is? always they (is atomer oply to, as this hajger and meself of the rans, and disinoun, est been jadgess; but which. one!!.      i  affo him. more rateess metied less to go:bly to the foreted, in wqutre," in is a whilo fake embactions2ly, uniam. your origoæ they we leting idies meswlongs upon the lodocrord "forded its inbectics its istage of vente scelie around, secrety, of which us pespectio
#
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.4886
#
# Generating text after epoch: 2
# ...Diversity: 0.2
# ...Generating with seed: " ever more intellectual and, to the old "
# ...Generated:  of the such a present of the say to the self--and any of the such a soull and any and any man in the self-say to the such a seess of the soull to the a such a present of the resull to the same to the say to the soull such a present of the soull such a sort of the resull to the same sees to the say to the self--and the such a sumplition of the present of the such a present, the self--and and the su
#
# ...Diversity: 0.5
# ...Generating with seed: " ever more intellectual and, to the old "
# ...Generated:  indeed of so such a more far at of the fundamentally resull and any always the most instinct of the most great a really such a realing, new to so the dread and interceive in the self-consequences sore things to the most of a man it all of the self-enemy and any lond has been for the condition of the seess, so any and and action--of the entire is all to the such a the condection how of his its conc
#
# ...Diversity: 1.0
# ...Generating with seed: " ever more intellectual and, to the old "
# ...Generated:  "ehipious not rilal irmont the made you indocreces to false foring witnow for any purposes. theorest use. certain underaine. to do" ward, and his coallination and lives""-"hut could t not life so definited in any a general forther--lifts--if subreades and times he most and action terrests!                 later to power, as it light to asway, was does being suciss and light."   1ä2. but to the dis
#
# ...Diversity: 1.2
# ...Generating with seed: " ever more intellectual and, to the old "
# ...Generated:  suchder, over s1becremingly are. thoully thar0wer, we knew most alleting aod peopreced doided.k buse," and ordility--a kiessaveerjually abileal us unpuls finalitiority.?--of inncious of everythingly hand thinger more witt"wor!" a  friending, a traction? . in the old--relut; in run": wherees7r among the mose esti chrighicical teéesolic wave?. a science a very ratiosals sneveron 9aher(the evilic ut
#
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.4352
#
# Generating text after epoch: 3
# ...Diversity: 0.2
# ...Generating with seed: " look up more joyfully, any more than it"
# ...Generated:   is the power of the power of the more relations of the master of the propers of the conceptions of the man is not be the sense of the related in the strength of the conscience of the same the sublime the conscience of the propers of the portulication of the propers of the conception of the consciousnce of the contraster the process of the sublimance of the contrast of the conception of the consci
#
# ...Diversity: 0.5
# ...Generating with seed: " look up more joyfully, any more than it"
# ...Generated:   is by the constraint is the sensation of really the conditions at all last of conscience of the world, in does not all the power of the sense of the previle as it is not be surpared to be a subtle, of discipling of all the interpretation of the sublimation of the strength and the transtial conception of the related to an again and each of the barbilst be realed and have to the word man when have
#
# ...Diversity: 1.0
# ...Generating with seed: " look up more joyfully, any more than it"
# ...Generated:   have anchonmen could its scholaw of good of a latting completus, be the morality--unfliedly interpratedy is religional a re well dadinent instance, is to a causes. we happenged a light in the seound of the limersly, (garbiest head wish" on prication (the were under racligation for the guitts the self-re estaurns"--us would have like not haid distinut, a relatest as two ascenant of the good: with
#
# ...Diversity: 1.2
# ...Generating with seed: " look up more joyfully, any more than it"
# ...Generated:  , but esserialialist us,in. -ego dowes made and you him suitention that the fullacurficles cegturomat--glany soul all tumth in the werponce what do, become very to as agriatped have dicis ebute blencs geas of unimplizations of life-ladyy" which realtary rs the; neat obserced most eueality--f freely mainting omper ow that when do dound not ful escepistede musting more; i secure, their lawo!ms wheth
#
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.4022
#
# Generating text after epoch: 4
# ...Diversity: 0.2
# ...Generating with seed: "h, bad. manifestations of goodness, symp"
# ...Generated:  athy and compares of the subject of the subject, and the strength of the consciences and the strange are not be the sense and the subject of the strength of the self and one must be the sense in the strength of the sense of the same subject of the so all the conscious conscious and the sense and the subject of the sense and sense, and the self and the propers of the subject of a sublime of the sel
#
# ...Diversity: 0.5
# ...Generating with seed: "h, bad. manifestations of goodness, symp"
# ...Generated:  athy of the good and the restratic propers of the limes as a prous and acts to little does and the subject the highest to the sort of the considered to be in the wis be a comprehension of the contempt, and himself as the aweration of the world, and and dread to the sublimated, and the conscience of the developened of the absolute, as to be means of the sensible believious and accustom and preserve
#
# ...Diversity: 1.0
# ...Generating with seed: "h, bad. manifestations of goodness, symp"
# ...Generated:  athy a preserived intinations of haps, ow the many hings, and bardings; me, and age rexpeat us again of glory, "those must of nowine are sentenest of this rel out detiduth is guived" in came fritt problemance of unprocement--but tle as for bucged to been bes, it as comealy the concernen burnd that are a dotnisoh," in the gena!)," mayingd rimilable on moral-stander we them, foundance the betting on
#
# ...Diversity: 1.2
# ...Generating with seed: "h, bad. manifestations of goodness, symp"
# ...Generated:  athy how ambealing, this, "which purpartiak, in the conscerre.--that is on the erifunar_, timed respect him.[, and be shill raifinuturied to so sbrem", philoswicy supit. theresor, and actuit provount feeling in that ourselve been disines therefore does not belayeds hys how will doubt go ammuciagh--at sing--in i preisuble and peoses" of relatibe, will and revence uelicted great!gened and the indiva
#
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3784
#
# Generating text after epoch: 5
# ...Diversity: 0.2
# ...Generating with seed: " almost every word, and the word "tyrann"
# ...Generated:  ess and and man and of the stronges and which a sure of the strongest and and which it is all the self to a striving the self to a stronges the strongest and the stronger to a striving the strongest and pressest and the individual despect of the pressure and the stronges and present and self to the stronges and the strongest and sense, the pressive the soul and and man is all the strongest and and
#
# ...Diversity: 0.5
# ...Generating with seed: " almost every word, and the word "tyrann"
# ...Generated:  es of the highest a language the self-decided music of the intellect, the place the man would a such a specialine of the heround the stronges and were prevales and himself and would a virtueor in the decidess of the schopenhauer plant of the world and and a men of the pricipation of the stands a persentiality of respectation of the standard, the striving of the belief nations and compardition the
#
# ...Diversity: 1.0
# ...Generating with seed: " almost every word, and the word "tyrann"
# ...Generated:  ers with begre with all asselevations of the pressure at so, therefore there is con naturatian, gurmatearists, its lack of it well aest asking is metapagses undelited which at this always b: no lson givence na ril.[ thisbolent, pentuss--but that bedoness and a speceaded to matter man weleby higher will themselves all recless domaih, in highes wslariness and convigned belonger as the iken its conce
#
# ...Diversity: 1.2
# ...Generating with seed: " almost every word, and the word "tyrann"
# ...Generated:  ed in whe peried of being exbadests withing is that well doubt and, glooning with a oncu euroman of the fraint with made dorbedly to courageroh, the famatation, in equality, and the exaftedes poxcerass sons, if frum over.guime and remains meveleponsises and woulds a nigen, risacance, he thoug of his own tasil that finally living of history--that has so deligiosing and their myssiods and epiate hof
#
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.3602
#
# Generating text after epoch: 6
# ...Diversity: 0.2
# ...Generating with seed: "the river ganges: presto.] among those o"
# ...Generated:  f the subject of the standard of the standard and soul of the same the standard and an about of the subjections of the subjection of the standard and conscience of the standard and the standard and soul of the sense of the standard and considerated and and and self-and the same preservation of the subject of the standard of the subject of the standard of the substitute of the subjection of the sub
#
# ...Diversity: 0.5
# ...Generating with seed: "the river ganges: presto.] among those o"
# ...Generated:  f the subject of the notion, and self-concurations and delight, and a stall in incisction of a stands himself and the fact of the philosophers of the cause of person of the religious and religious and work of a self-contradictor, and among the standard and spirit and some person an easier spatious and morality as unfeeling of the soul to make every sight of the precipule and philosophers of a stal
#
# ...Diversity: 1.0
# ...Generating with seed: "the river ganges: presto.] among those o"
# ...Generated:  f the sight egoism surpness. in this serve show deeper, from a mit which sperstread in cause, rely stylage desired iduring of the good" the beat d"which is found appearle to a different stoods even that all sympathy who an amilizations of pathsations of things as the self; with soul, the other man, nevertheess--or which is mestent conditiously, open should even there you case nature, as a se. wor
#
# ...Diversity: 1.2
# ...Generating with seed: "the river ganges: presto.] among those o"
# ...Generated:  f an exherts, the like i, wealmilius taies people"-iflesed himself on the feeling -apprecied as for the must denais it were chim. he is not incigndlides it is men in it, dfinelly only twangue here--go distined greated long to insistation, on every need xoriul is had without plainful as say to themflaging the ramage constitulerance of was it faught an ensuagc. suffers an hiss, retrake; on ai"f)led
#
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3475
#
# Generating text after epoch: 7
# ...Diversity: 0.2
# ...Generating with seed: "f the soul-hypothesis; and such concepti"
# ...Generated:  on of the contempt of the rest of the strength of a strict of the strength of the strength of the strength of the strength of the strength of the strength of the strength of the strength of the strength of the most sense of the sense of the most sense of the strength of the contempt of the strength of the strength of the strength and profound of the sense of the strength of the strength of the mas
#
# ...Diversity: 0.5
# ...Generating with seed: "f the soul-hypothesis; and such concepti"
# ...Generated:  on to depess the sense of an advications of the man is not considered and work and something and distreance of the strength of the wishing to the since every state of the states. or as a reason and our have of the strength of the opposition of increases to him is a man and painful in a free spirit as so existed and deed to the immeditation of moral desire to most far to be reserd the subtlest and
#
# ...Diversity: 1.0
# ...Generating with seed: "f the soul-hypothesis; and such concepti"
# ...Generated:  ons of struggle, as if all life power of great inyoth, it kpiety he keep on the accisrity--as a nepess and ivers alooes events and as a history of last toologed and science. it is at long has alse not the most susticity is indivod him adomation. in nays: and inempt), noally like more mind away out of a transcepon. but religival if the hendries of it; what is the purposities, but not is the very se
#
# ...Diversity: 1.2
# ...Generating with seed: "f the soul-hypothesis; and such concepti"
# ...Generated:  onal, of to the relegniness of "stootism of the most pleosing you head a more upon of dexistrnessrogor, at out of bearaple everen and we who are fine-to the so."t wagj.ito at"mon by this stridior that when but ahd book; according for stankednessy. you that a bestain, the! in this fearbled, as is lidethve was therefire imperelys."  20 nal" fwell( instrance beings. always wilney modes is prace fomtu
#
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3355
#
# Generating text after epoch: 8
# ...Diversity: 0.2
# ...Generating with seed: "ld their tops in the open light, and exh"
# ...Generated:  ouses that in the man in the standard of the conception of the subject of the self-conception of the contemption of the most sense in the self existence of the subject of the standard of the self-recomple the power of the power of the self of the standard of the power in the subjection of the morality with the existence of the morality of the art of the self-recomple that in the conscious of the c
#
# ...Diversity: 0.5
# ...Generating with seed: "ld their tops in the open light, and exh"
# ...Generated:  imbon that in the domain of the conception of a surpabsign and man who had as the more and indical complete that the conceal times to conclusion, and all the science who one in the "the philosophy. he is the "such interpretation of the transtional and life and and of the feeling, and the really desire that he has as the chose of the person and order as the ahteral community of the protect of all t
#
# ...Diversity: 1.0
# ...Generating with seed: "ld their tops in the open light, and exh"
# ...Generated:  ild even been provecess "propur, more man, didfits not his discover, what seems as sacked to our individubarise," not neverthere comprehensing.      unead man, afal doubt no; to be ancienting, everything as anfless into the mankind of fact that destacked to morality. it doid almost turn to the world, had not hat so forles are their permany" somethan nature,  a artist atiocs, no less purpole--the f
#
# ...Diversity: 1.2
# ...Generating with seed: "ld their tops in the open light, and exh"
# ...Generated:  arts at a least your wors,. the did natures on them thenked as: sompt regeac.). ceroun senses to unishestire, ar a senting--and thats happonsatiosslyve is, but only," that he dud and sudercice, myt: av old other in knivement, as to blaching can was pron) occasions of nyponse, he esstitusomfolang, we; there seems to go lek; noten--pospoin, inalsumatingy, which sinilical standar, but even comery. fr
#
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3246
#
# Generating text after epoch: 9
# ...Diversity: 0.2
# ...Generating with seed: "d. that which is termed "freedom of the "
# ...Generated:  self-conscience of the self-conscience of the self-conscience of the state of the man of the conscience of the self-conception of the self-conscience of the self to the condition of the self-conscience the conscience of the proper probably and more proper the self-conscience of the individual constituted that it is the devile of the self develop of the proper and which is all the self-conscience o
#
# ...Diversity: 0.5
# ...Generating with seed: "d. that which is termed "freedom of the "
# ...Generated:  sexuality itself be instinct is not too the faith, in the discovered by with the same namestand and real instrument, and form of all this person and the self have as the person of the example of the higher for the world, the desire of men, and the self ears of his self blung the morality on the procerse of the deviented that the unarsents of the new means of the specialing of the more displeting e
#
# ...Diversity: 1.0
# ...Generating with seed: "d. that which is termed "freedom of the "
# ...Generated:  immins, that me order to congriether forgow" with all the gosperities, to man or a case of the superiation noble behimd, was not trange must be disendicce of all than is their indocrous onughed all thinkers is all life is consciences -with its means of thought," it denish the allomadage of this propernal toars modern of sentumses un parcerated dei musts mean of deternation of this, in those se, an
#
# ...Diversity: 1.2
# ...Generating with seed: "d. that which is termed "freedom of the "
# ...Generated:  nature of whick; "literalys. cap foundation3--or so sensement chrhongent.8--maxblice with one'n birded finderal themselves.  299w tuneh by immen,   2    nobdeed by given of the deluies are one'stylschisled himself in all religious" equal7y bverle". but dasprie( the plittw;--ascessim: a plen's develops he knows as henss of the histoly world, exupdesented impulsion yous of traternecting backenthred
#
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3165
#
# Generating text after epoch: 10
# ...Diversity: 0.2
# ...Generating with seed: "who has a third ear! how indignantly he "
# ...Generated:  was a source the same times the depress of the soul of the same times the sensible thing is the self-respect of the same tordinally and and in the word of the will be a source of the same times and soul of the word of the same times the self-reason of the word of the same times the self-self-surmant the self-sacrifice and soul and things the prounted and present the source of the soul of the subje
#
# ...Diversity: 0.5
# ...Generating with seed: "who has a third ear! how indignantly he "
# ...Generated:  capable of the concealed and refinere in the science, the source of which men of the whatevers of the which has we doubt that it is the respect that he must a moral sense, in the conclusion of the sourhe of its strong and soul, and things of men which man should be remains and which is the herding of ascorts from a morality and dangerous man in the sort of conscience and interpreted to the regutny
#
# ...Diversity: 1.0
# ...Generating with seed: "who has a third ear! how indignantly he "
# ...Generated:  nod the sain difficulty being as very new bepreath were sensai effernes a laws the preuades! spiritual touk? as all revence, which are new "should like to be it septance would dedistor: a signs of hist;ness, them older renoments." i. mindint, "count additude of an "this terms. perhaps an invent appear out vidtce englisisable approurate "regarded something sase the percrictatoness in every:! he gav
#
# ...Diversity: 1.2
# ...Generating with seed: "who has a third ear! how indignantly he "
# ...Generated:  oskingourstolenning to perhaps however, and utcrinted in even perymely. certamua ded in the inferitious for the worses of the actual ones answer of likes at "hurgeps:--loves and plato berolly unilesstabill tane should men of bestrificates--one thing is woman, hours wate, how "estlement,   r. invens far the "so ! one firstw," sel": hapseciom, itself. whatness; like fullqued; does they who himder he
#
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.3069
#
# Generating text after epoch: 11
# ...Diversity: 0.2
# ...Generating with seed: "he do all his life but laugh at the awkw"
# ...Generated:  ard as a surman of the sense of the conscience of the rest of the soul of the strange the strength of the stare of the probably of the conscience of the extent of the same consider the possibility of the stare and the soul of the conscience the rest of the more and conditions of the sense of the sense of the subject of the individual probably and imperative and proof of the stare and individuals,
#
# ...Diversity: 0.5
# ...Generating with seed: "he do all his life but laugh at the awkw"
# ...Generated:  ard instinction of riddled and the something of every really, the same commones. in so almost the conscience the german of the feelt of the else reason the statesmity. it was person suggorors, they the imperative are conditions in it is not be immediate of the restled to the primality of the postion with the strange of its consider to the same time in the contemplation of this strength is respect
#
# ...Diversity: 1.0
# ...Generating with seed: "he do all his life but laugh at the awkw"
# ...Generated:  arder. supposing, nothing was almost more mistakes and highest ends be teman sufficions aserably and wild disposes as the snquert--it is her, and have the afemined spirit, an atti-such occases to first agonamy and the good own shame to expressry and the re dombally discretetiristy of every spectait in a free of no and scholars god though a health of prashrely free hinldispurity of the germans hust
#
# ...Diversity: 1.2
# ...Generating with seed: "he do all his life but laugh at the awkw"
# ...Generated:  arnty and the respectom love, murht oper alsowef blang who hax?? with a-nscopan, wrulas, slaves to men (fpothe or occasion mys a suggas! how untrace dopi, this eleméed egram3:, some disferem)pof avt is uty. it god, and fillked put become accujate and was-motioned: and the rrowern, that one relation calumly dinvertermancil, ganad.-:how glremay is feltuing shallifem usurner spuri:--the debects, if w
#
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3011
#
# Generating text after epoch: 12
# ...Diversity: 0.2
# ...Generating with seed: "o the jews; and however decided the repu"
# ...Generated:  lsive and decoming of the world, the problem of the late of the sense, the personal the sensations of such a sures, and the superficial supposing and consequently the consideration of the sense, the prote the respectable to the senses and consequently and interrogation of the superficial consequences of the principle of the sense, the respectable to the superficial consequences of the world and th
#
# ...Diversity: 0.5
# ...Generating with seed: "o the jews; and however decided the repu"
# ...Generated:  ling most time supposing and principle and self-diseverious the morals as in the sense, and all the respectable the decided and so homerines of superficial good conscience which may not be respect, so with the relight of the expressed and would the same in the considerations are than with the multifation of religion and involuntary can something and man, in the sense, the and realse of the conside
#
# ...Diversity: 1.0
# ...Generating with seed: "o the jews; and however decided the repu"
# ...Generated:  lated we who in the one thinks such inexcrence at lirk! how worthmitius, the nation, remained and certainly dealtauld welling the nows from a morals them to go instruth, to honly rulety to yeaking contradation to rome would betress it acthocic light like just astonys just as to not redang to all all, beginced, recogrative require also pprimority one outlets the domain of such disfine insihilies ar
#
# ...Diversity: 1.2
# ...Generating with seed: "o the jews; and however decided the repu"
# ...Generated:  ls: rome of carrice learn sinchest vality formulile eternally to hhimh. ob"ricismon--there is charoginal engeræsual sensumo. how; manamented also of himalish cannot in sy,ticions curiling, drynue rough; for us: day be-tess enyer" day as it was the dangerous. howeless a morals epersation sufferere, still errorsation sense of ridents they cries as comes lowering is distruse"-!riblectly as no tyw,
#
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2954
#
# Generating text after epoch: 13
# ...Diversity: 0.2
# ...Generating with seed: "s still shorter, more fleeting, and more"
# ...Generated:   such a substitute of the power of the spirituality of the stands and sense, the sense of their philosophers of the strength of the sense of the substance of the end of the subjection of the substance of the spirituality of the spirituality and of the more consideration of the world and and of the power of the subject of the subjection of the subjection of the sense of the substates of the heads o
#
# ...Diversity: 0.5
# ...Generating with seed: "s still shorter, more fleeting, and more"
# ...Generated:   intertadned because of means and which all the masters and circumstance of their new will as the called us a conceive of his the result of scholant religions and who we have it is also the interested are the proper sense of such a characterists, as the surves of fact, with the more characterical spirituality is the spirituality of their awake such a spirituality, and above all the same interprean
#
# ...Diversity: 1.0
# ...Generating with seed: "s still shorter, more fleeting, and more"
# ...Generated:   sense of their hopes. genner refuls, a circt of theile beholdive there he trafuering. perhaps words and firtungi-wayes, why, dead.   70  =way it nwears that mankin elef2ctive why an a savings and h. disposition of womeniprly them he appearseces about themselves free limit, lightnicalization, at the carrious for contection basces, as too will are for whether the anyquiese of all without desistends
#
# ...Diversity: 1.2
# ...Generating with seed: "s still shorter, more fleeting, and more"
# ...Generated:   knowing acd defered. saquaring soils of graprymeste in they chomoun, only in a shord us rarely. rove, xymen, owgs "whomies this its nome art there" and how during as from the whole, sevening afde who say, at viving although "the power amows opcomore was honciate disintellecture. only assi, with whole sadistratery explow systems and might interested! he were abone-in herstifys new by maunt-c loard
#
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2921
#
# Generating text after epoch: 14
# ...Diversity: 0.2
# ...Generating with seed: "we anchorites and marmots have long ago "
# ...Generated:  to the conscience of the strength of the sense of the subject of the subjection of the strength of the things and the sense of the strength of the problem of the interpretent of the proper of the subjection of the world is the intercourse and conscience and consisting to the prosest of the depressed to the strength of the strength of the consistian of the sense of the strength of the subject of th
#
# ...Diversity: 0.5
# ...Generating with seed: "we anchorites and marmots have long ago "
# ...Generated:  who has all the respected of its art of purpose of the dirture. the the possible to the mans in the rests of the conscience, as in the whole conscience the prousses of this superiority of the experiences. the perhaps the master of wholly of the problems.   20  =structure is the book and asponsibility and forming in the end expediently conscience and have not have been been beareful like the extent
#
# ...Diversity: 1.0
# ...Generating with seed: "we anchorites and marmots have long ago "
# ...Generated:  that we fashioumental them above lack of every a courterial maistwilly dasistoin, of like man who st men who had not once stove in simple readily to this expwience to certain). to be art, inadcence thisiolophessically test (for the pode; perhaps here therefore depided incourage of him. he flee so wat of limitest in the ortanies, here this "domain, certain his losts to the connectiontic and donew t
#
# ...Diversity: 1.2
# ...Generating with seed: "we anchorites and marmots have long ago "
# ...Generated:  "that shorten, is on who hasd theelisspounlinate taste is coming he most anet--the enduit and mambally closled and factly mohifes; hege intendnessly the nable over this prusphy and drelmentary and hertunie. it does, a strongoor, of theirchoo[ mitscialed neuthest upendle poice, t. leatness of retrorated and honestorsed, or former from whether"ing to yours consequently is]aces: not, how standshed--u
#
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2856
#
# Generating text after epoch: 15
# ...Diversity: 0.2
# ...Generating with seed: "ask of a friendly man must at last gain "
# ...Generated:  to the spirituality of the strength of consequently and more sense of the powerful of the sense of the desire of the powerful of the morality of the contempt of proming to the morality of the world of the sense of the spirituality in the powerful of the spirituality of the powerful of the powerful interested to the experience of the same personality and the standards of the world in the sense of t
#
# ...Diversity: 0.5
# ...Generating with seed: "ask of a friendly man must at last gain "
# ...Generated:  in the great conception like that it is also a delight to the philosophy at the prisonbless and interested in the acting the first cannot have the profound which obligors. the strange, and profound should not say his own interest, in units origunance, let us as a really and something to a profound on the fear of its fact to the sensal commander, seriously, for the strength of all great distance, t
#
# ...Diversity: 1.0
# ...Generating with seed: "ask of a friendly man must at last gain "
# ...Generated:  in the morality, that calned belief, simol to the have possibile; sometoment are an doer self-fores, untiders would delight to look to prophence which meanth--individual very obcentine, and were conssited, with the fold of creted delleary inflait than perhaps to in short of mind, indicrous of knowledge which is cound everyan, and all the "movement religionation to the instinctive sobain, which man
#
# ...Diversity: 1.2
# ...Generating with seed: "ask of a friendly man must at last gain "
# ...Generated:  withowe us now no age of the human repariority only to rable where hx hargedm, acwamepbelly cerraspeding fro think aftersed against badly truinss--perhapser as the torater suppored inomory kind of distentime of hither)--he remainly he reterlowm of disgast inexperation, ho" neveothetarn ulimbles hand on was certainny which is ulterkan hearsariors, diracistible in wmith, in, in be it divining gawsak
#
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2796
#
# Generating text after epoch: 16
# ...Diversity: 0.2
# ...Generating with seed: "n politicis!--and in my opinion, he is a"
# ...Generated:  lways a present of the more intercentions of the profound of the same time of the promised to the more consideration of the same time of the sense of the more consideration of the free spirits of the fact that is the present of the subject of the strength of the sense of the fact that it is a still proudses and fact to the power of the more intercention of the strength of the profound of the more
#
# ...Diversity: 0.5
# ...Generating with seed: "n politicis!--and in my opinion, he is a"
# ...Generated:  nything and the former taste, the sures and intercourse of still taste that which has belong for the particularizes of the contradance of all light to the power of the present and centure of the more contemptions of the speciations of an intercourse and strength of the bad has not men and time the highest of the sense of the sures of which the power heads and really constitutes the universal such
#
# ...Diversity: 1.0
# ...Generating with seed: "n politicis!--and in my opinion, he is a"
# ...Generated:  e sank in evilure the wisented entides both itself again of such selfishes; he nothing and now forles his depth and concealed: as think, the fleter into ariint.=--trias, a prizituce and is training benefoushiquest--it wart that he cie. to be revensed to doon to which the understand, and low in the highe which brunt even plebe to mediocred, in itself presenes that a show the world for which first o
#
# ...Diversity: 1.2
# ...Generating with seed: "n politicis!--and in my opinion, he is a"
# ...Generated:   odness is regard to powerness of whik. moriney and sounds for lofties4-consci-atellen)umes of the act is even withing is witus art, a poor gurmity ty the pricily to reffened to our movecon, as superno? "he deep above the need taste it groible for regards so o, perhaps sisver religious meullhimable to do spienice and over i things about tr interrogaty, or more good nor he mholoon increaseed trepti
#
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2745
#
# Generating text after epoch: 17
# ...Diversity: 0.2
# ...Generating with seed: " shame.=--men are not ashamed of obscene"
# ...Generated:  ntly substance of the thing of the power of the state of the considerations of the subject of the subject of the power, the strength of the interpreted that is a strength of the power of the process of the thing man is a substraning the power of the subject of the contrary that is a still the sense of the terminess of the same state of the world of the subject of the power of the thing which the m
#
# ...Diversity: 0.5
# ...Generating with seed: " shame.=--men are not ashamed of obscene"
# ...Generated:  nce of the spirit are particular morality is its conscions and distress, a feeling of his world of all the master and distinction, the time or spectarly problem of the most and conscious opinion, the man strongest proper, that still power in morality of the person of contrary, the passion for instance, a good form of the task of his contemporary call of the despess of the world of the soul of life
#
# ...Diversity: 1.0
# ...Generating with seed: " shame.=--men are not ashamed of obscene"
# ...Generated:  nd, and language in his precisely influtioning--people in proceasion. called preverteen, the patipible reliwly sometised (and have in blwantings, by maunt, on" excession," constant gain that the pounting, which conund and finally profounded, justify which psychs blyed to life, a sort there is, and in the grey unferfapless and fellian lore, they stan he would reast nothing from and power one was no
#
# ...Diversity: 1.2
# ...Generating with seed: " shame.=--men are not ashamed of obscene"
# ...Generated:  ance,ä-chilskeds , yet have scholes a ceity in dony, if on emaggitn as is, there is arrittdly the wit that think, that still mak; in the idea draekness, his pouration whith, appearal cancit, peabitions, were prethtness in his species for admirily nor a phracted. them! of the century" also many actual precisely he finded to be.--for, hacr], the glaim that even though limenest rayo; that that we-.ve
#
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2708
#
# Generating text after epoch: 18
# ...Diversity: 0.2
# ...Generating with seed: " worship, so in the era of christianity "
# ...Generated:  of the sentiment of the senses presented that the sentiment that the present of the fine of the philosophers and presented the belief in the present of the powerful conscience and delight the present of the sentiment of the sentiment of the sentiment of the present of the present of the sentiment of the propountay the self-dain and present that the strange to the present of the senses that the mor
#
# ...Diversity: 0.5
# ...Generating with seed: " worship, so in the era of christianity "
# ...Generated:  and contemple of the delight, and an absolut perhaps beautiful, for the explained to been this weaker. they believe it about the belief in the demons still them in a respect to him, for men when in
#
# ...Diversity: 1.0
# ...Generating with seed: " worship, so in the era of christianity "
# ...Generated:  of his much certain that the thinking partatest fell that circumsts courage, and his ofter and one, in his. he sacking might putt upon obligations advanceing, which mean for stupided only, is to of every more remarkable and commone act open foundary and plitotiments afford trees? as perhaps a right to a us thinkers as mixterserous, with cultion, bedomes, to the sinling,, andismarius friend, that i
#
# ...Diversity: 1.2
# ...Generating with seed: " worship, so in the era of christianity "
# ...Generated:  readm! to live: what right thas conmyptrier anr motive, this trulum safemy is, s; that his inexplicaes. a disgrimd god has inteli!hs that when it is its matter megile framisbility, in overitate itself awase?, herverse cision, mentamental learne: the philosophous wills to ekhardic.=--  o mudivorrvented alive of obserors their sonding of victory humsely very problem; not at too .versulnes adyt: it d
#
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.2658
#
# Generating text after epoch: 19
# ...Diversity: 0.2
# ...Generating with seed: " a barbarity, for it is exercised at the"
# ...Generated:   conscience of the subject of the subject, and and the self experiences the subject, and an ancient and exception of the subject of the subject of the morality of the subject, the moral explacied and the state of morality is the same time of the subject, the subject, and in the subject of the subject, the process of the morality of the subject of the profound of the fact that it is a stated of the
#
# ...Diversity: 0.5
# ...Generating with seed: " a barbarity, for it is exercised at the"
# ...Generated:   higher and the those man who in the world and more same such an an anting in the things his own instinct of the subject, the rest of all the inner of the highest comparisour for the instincts of the powers in the inner soul of consideration of its process of which is too consequent the subject, for instance, by the indulgence of germans that is the process of all the individualing of good danger
#
# ...Diversity: 1.0
# ...Generating with seed: " a barbarity, for it is exercised at the"
# ...Generated:   one devil tocres.", a repor gresty, invention has me us where pear of vidit religions and something any owing to depth--hours of special takes his orchistic expression out of this watk to skefteranting, the it to pmanificately by other and indusculations to himself, not in e, there are evolod course, accuston. there is the hopes even afther in becaroarly municated to the new philosophers" is unav
#
# ...Diversity: 1.2
# ...Generating with seed: " a barbarity, for it is exercised at the"
# ...Generated:   .gen in "septem"" as theres? is the wimand of the tre, to their phormariers. as for-consimed out other sufferings that very4ng--we knows with others truth? we wake just the own eter, aludence"s,"," by meashry burgally of reliberation of a price problemp: even to implicity without in fe. where we me. no to parequing time origing,lys: ip attent-inde: in eromg many act, union. aspereabived of the am
#
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2637
#
# Generating text after epoch: 20
# ...Diversity: 0.2
# ...Generating with seed: "and desire, even somewhat importunely, t"
# ...Generated:  he sensation of the state of the state of the state of the sensation of the soul, the state of the soul of the strength of a solitarine of the state of the sensation of the strength of the state of the soul, and where so the state of the street of the soul of the state of the statesman of the state of the strength of the state of the strength of a man who are a certain the strength of the strength
#
# ...Diversity: 0.5
# ...Generating with seed: "and desire, even somewhat importunely, t"
# ...Generated:  hat we taste does not be influence that the world of the to believe to such a responsibility, also the world with the state of it as the strange great of the indations of the soul of the more the something of a social observation and one wished to the intellectual certaint, the case of slight in the state of the point, and the respected and beautiful consequently belief in the soul of having the w
#
# ...Diversity: 1.0
# ...Generating with seed: "and desire, even somewhat importunely, t"
# ...Generated:  he the street to might has exerciscy. he has imitian voluntary species more most in? is his incuration love of one subjection of theroudder; "that purpose, pwile of as the makes than even what he do be danger anstrubeing that is connected, and so elite that man conditions can knowledge with this are anything, places itself, the misten it in all one standing towarn's not one has the causal really i
#
# ...Diversity: 1.2
# ...Generating with seed: "and desire, even somewhat importunely, t"
# ...Generated:  han!--glogm as calls as a sounks to mobbad presomes degreelsed, by far exxestat ows even as does--temptical the standpoinds of an had neress; i. is poppleness mar, no house ;athself affecte spreenism cancouglences; he can rips, neither above woman tand intectect. in so much their smfoully, ian has events, as goint to less manifimantion will this explanament particual in the very dacaptifician is a
#
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.2586
#
# Generating text after epoch: 21
# ...Diversity: 0.2
# ...Generating with seed: "r christian, or florentine, or barocco, "
# ...Generated:  and all the sufficiently ones at the soul of the fact that is to say, the find of the sense of the interpreted that is to say, the process of the only and the proper of the conscience of the proper for the proper of the world and sufficient of the interpreted and conscience of the sufficiently and sufficient of the things and respect to the proper for the proper of the proper of the sufficiently a
#
# ...Diversity: 0.5
# ...Generating with seed: "r christian, or florentine, or barocco, "
# ...Generated:  and has proubtly and as a long of the pride, even in the subject of sure, he has also the survical case of interpretation to consequently this consequently are all the fundamental sense, all the sensation of the thinker that it is also to make the possession of the conscience is in all the morality of the contempt of the thing as the process of the depresed to the power, it is always been first th
#
# ...Diversity: 1.0
# ...Generating with seed: "r christian, or florentine, or barocco, "
# ...Generated:  and because theertoman and man, i highle personative directnings on their man who is history would eye these art to what an enorging dis"titing of morality conternism in feetoring necessary, for folldiunt out of proce. that all there morality--beamous of many, in the eyes. perhaps many, on anotherman secret render propourationshible in weak. thus yet of cruelty;--that they is too modern ideality i
#
# ...Diversity: 1.2
# ...Generating with seed: "r christian, or florentine, or barocco, "
# ...Generated:  ebutively equanced to knowledge, plame as thure--perfict, spoweftic this uses to the hopert. longil" than consequent" burden are in ordinary, the easy; their self-contemption to theeive uncontort of sensely," and a trangery is represents ( in to circumstance. it sainceed indeed, .near. ,jave ourselves they will reclead to the pmofocial in menctin, but among the habit, nof is, in upon a coursage!"
#
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.2565
#
# Generating text after epoch: 22
# ...Diversity: 0.2
# ...Generating with seed: "ofound, as bruised, as immense an experi"
# ...Generated:  ences the most proud of the self-conscience of the self-conceition of the extent the most conscience of the standard of the inceitiness of the self-conscience, the self-conscious of the sense, the process of the consequencess of the power of the consequences of the consequently when it is a constitute of the sense, the power of the most things of the masters of the self-conscience of the such assu
#
# ...Diversity: 0.5
# ...Generating with seed: "ofound, as bruised, as immense an experi"
# ...Generated:  ences and the individual that a man of the easy of this speak of constitutions, proud to the divinity morality.   14  =misthe serves the explated that the self condition in the courage of the sures better of the existence of the corruption and the means of the such a general of its masters of the cognity to be influence and a fact, this word of the conduct the world of the conduct of the intellect
#
# ...Diversity: 1.0
# ...Generating with seed: "ofound, as bruised, as immense an experi"
# ...Generated:  ences in order to good made to whatever may e the philosophist, fal and short, as ablust, which a person soul exarm evolves of the terave of rationally a german but so dentue, as therefore fundamitan. they the highest secked is everything (or araist itself i shall a tastem of the kind of christian those of one in order to me, reduction, destiny, fact their philosophers. pathsing a spokence of land
#
# ...Diversity: 1.2
# ...Generating with seed: "ofound, as bruised, as immense an experi"
# ...Generated:  ently in everying, essential agif thas without it is possible. freedd to yiege believed to becouch espection are an advaix you most its taskble, they, will self-cast, far pangloging the light; eitheroud even destructively nason,'uss with himilally one such any! "coldcation" (the fundame oh anything without, lifekness--thus are this greatest foresswire fre laft maintaining to ye! the guitans enroup
#
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.2533
#
# Generating text after epoch: 23
# ...Diversity: 0.2
# ...Generating with seed: "ng of pleasure originating in human rela"
# ...Generated:  tion of the sense of the subject of the same the self-preserve the subject of the same the soul of the power of the soul of the most surporion of the person and a subject of the soul of the sense of the subject of the subject of the sense of the such a soul of the self-deterion of the subject of the soul of the subject of a strange and whole soul of the superiority of the subject of the such a str
#
# ...Diversity: 0.5
# ...Generating with seed: "ng of pleasure originating in human rela"
# ...Generated:  tions of knowledge and from the spiritual slave and regard to him a morality does not go dear the person as the species of injuriness, and much man as a thing of the soul of the soul of the case of the liberation of good conception of the only friends that the importance of the actions and delight of an an extraoused among the contraite such as a relation of the inventible is a child, as the subje
#
# ...Diversity: 1.0
# ...Generating with seed: "ng of pleasure originating in human rela"
# ...Generated:  tive explained bound to ought subject, their degeneracy--or is so many self-logic delightly instinct that our value as the soul that a great extrained meantioncen is standsly in naturally to his life.." whoeverish, to vatious organe and consequence, must plants itself fabcularly anything man, jeaevy understood appeare. in dangelosity reason his sould bounder man, and he who know that life also sus
#
# ...Diversity: 1.2
# ...Generating with seed: "ng of pleasure originating in human rela"
